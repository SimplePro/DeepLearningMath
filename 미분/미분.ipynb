# %% [markdown]
# ### 미분이란?
# - 미분은 변화율을 나타낸다. 정확한 정의는 '극한으로 짧은 시간(순간)' 에서 의 변화량이다.
#
# - lim h->0 은 극한을 나타내며, h 가 한없이 0에 근접한다는 뜻이다. h 를 한없이 0에 가깝게 줄여 x 의 변화 비율을 구하면 그 값이 바로 y = f(x) 의 미분이다. 또한 y = f(x) 가 어떤 구간에서 미분 가능하다면, 해당구간의 '모든 x' 에서 성립한다. 따라서 위의 식의 f`(x) 도 함수이며, f(x) 의 도함수라고 한다.

# %%
from IPython.display import Image
Image("./도함수식.jpg")

# %% [markdown]
# #### 경사하강법
# - 경사하강법도 미분을 이용한 알고리즘이다.
# - 손실함수를 그려서, 스텝사이즈를 간격으로 점프하며 구간마다 변화량을 측정하고, 변화량이 가장 적을때를 적합한 모델이라고 판단한다.
# -> 이때의 변화량을 미분을 이용하여 구한다.

# %%
Image("./선형회귀 비용함수 식.png")

# %%
Image("./경사하강법.png")
