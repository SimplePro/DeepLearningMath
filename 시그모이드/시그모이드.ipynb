# %% [markdown]
# ### 시그모이드란
# - 시그모이드 함수는 함숫값이 0~1 로 압축된다.
# - 로지스틱 이라고도 불리우며, 현재 분류 작업에 널리 사용되고 있다.

# %%
from IPython.display import Image
Image("./시그모이드 함수식.jpg")

# %%
Image("./시그모이드 함수.jpg")

# %% [markdown]
# ### 시그모이드 비용 함수
# - 시그모이드는 선형회귀에서 쓰이는 비용 함수와는 다른 비용함수를 사용한다. H(x) 를 예측값으로 하면, 수식은 아래와 같다.
# - 아래와 같은 비용함수 식으로 경사하강법을 이용하여 최적의 모델을 찾는다.

# %%
Image("./시그모이드 비용함수 식.png")

# %%
Image("./시그모이드 비용함수 식 정리.png")

# %%
Image("./시그모이드 비용함수 그래프.png")

# %% [markdown]
# ### 시그모이드를 분류 작업에 사용하는 이유
# - 분류작업을 선형회귀로 하게 되면, x 값의 범위가 많을때, y 값이 계속 감소하거나 증가하여 분류가 힘들게 되기 때문이다.

# %%
Image("./선형회귀 분류 힘든 이유.jpg")
